# %% [markdown]
# ## Assignment 5
#
# Author: John Courtright\
# Course: ISAN 5357\
# Instructor: Dr. Zareef Mohammed

# %% [markdown]
# ## 1) Create a class 'BankAccount'
#
# Attributes:
#
# - account_number -> string; unique id for each account
# - account_holder => string; name of acc. owner
# - balance -> float; balance of account
#
# Methods:
# - deposit amount into account
# - withdraw amount from account
# - print current balance

# %%
# List of all accounts
accounts = []

# BankAccount Class
class BankAccount:
    def __init__(self, account_number, account_holder, balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance
        accounts.append(self)
    
    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited: ${amount:.2f}")
        else:
            print("Deposit amount must be positive.")
    
    # Method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew: ${amount:.2f}")
        else:
            print("Insufficient funds or invalid withdrawal amount.")
    
    # Method to display current balance
    def display_balance(self):
        print(f"Current balance: ${self.balance:.2f}")

# %% [markdown]
# ## 2a) Create 3 Instances of BankAccount

# %%
# BankAccount(AcccountNumber, AccountHolder, Balance)
test1 = BankAccount('123', 'John', 234.65)
test2 = BankAccount('456', 'Caden', 87.78)
test3 = BankAccount('789', 'Lainey', 123556.46)

# %% [markdown]
# ## 2b) Verify Objects

# %%
# Print values for each test account
for account in accounts:
    print(f"Account Number: {account.account_number}, Account Holder: {account.account_holder}, Balance: ${account.balance:.2f}")
# Out:
# Account Number: 123, Account Holder: John, Balance: $234.65
# Account Number: 456, Account Holder: Caden, Balance: $87.78
# Account Number: 789, Account Holder: Lainey, Balance: $123556.46

# %% [markdown]
# ## 3a) Test 1: Deposit and Withraw with no error, Print balance

# %%
print(f"Testing {test1.account_holder}'s account:")
test1.deposit(101.54)
test1.withdraw(50.00)
test1.display_balance()
# Out:
# Testing John's account:
# Deposited: $101.54
# Withdrew: $50.00
# Current balance: $286.19

# %% [markdown]
# ## 3b) Test 2: Deposit with error, Withdraw with no error, Print balance

# %%
print(f"Testing {test2.account_holder}'s account:")
test2.deposit(-54.92) # Errpr
test2.withdraw(25.00)
test2.display_balance()
# Out:
# Testing Caden's account:
# Deposit amount must be positive.
# Withdrew: $25.00
# Current balance: $62.78

# %% [markdown]
# ## 3c) Test 3: Deposit with no error, Withraw with error, Print balance

# %%
print(f"Testing {test3.account_holder}'s account:")
test3.deposit(6782.12)
test3.withdraw(1000000000.00) # Error
test3.display_balance()
# Out:
# Testing Lainey's account:
# Deposited: $6782.12
# Insufficient funds or invalid withdrawal amount.
# Current balance: $130338.58
